# %%
#import the packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Session_1**
# **step-1**

# %%
#read the file bank_data
bank_df=pd.read_csv(r"C:\Users\surya\NareshIT\Data_files\bank - bank.csv")
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
#1)type
type(bank_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#2)shape
bank_df.shape
print(f"The Number of rows are {bank_df.shape[0]}")
print(f"The Number of columns are {bank_df.shape[1]}")
# Out:
# The Number of rows are 4521
# The Number of columns are 17

# %% [markdown]
# **step-2**
# **Data Quick Check**

# %% [markdown]
# **1)Head**

# %%
# access first 5 rows with help head
bank_df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# **2)Tail**

# %%
# Access the last 5 rows with the help of tail
bank_df.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %% [markdown]
# **3)Shape**

# %%
# shape is used to get the number of rows and columns
bank_df.shape
print(f"The Number of rows are {bank_df.shape[0]}")
print(f"The Number of columns are {bank_df.shape[1]}")
# Out:
# The Number of rows are 4521
# The Number of columns are 17

# %% [markdown]
# **4)Size**

# %%
# size means the number of rows * The Number of columns
print(f"The size of bank_data is {bank_df.size}")
# Out:
# The size of bank_data is 76857

# %% [markdown]
# **5)columns**

# %%
# Get the column name with the help of columns
bank_df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# **6)Data_types: dtypes**

# %%
# get the data types of columns through the dtypes
bank_df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
#creating the list of categorical columns
#create the list of Numerical columns
cols=dict(bank_df.dtypes)
cat_col=[key for key,values in cols.items() if values=='object']
Num_col=[key for key,values in cols.items() if values=='int64']
print(cat_col)
print(Num_col)
# Out:
# ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y']
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
#creating the list of categorical columns
#create the list of Numerical columns
l1=[]
l2=[]
cols=dict(bank_df.dtypes)
for key,values in cols.items():
    if values=="object":
        l1.append(key)
        #print(key)
    elif values!='object':
        l2.append(key)
print(f"The list of categorical columns are {l1}")    
print(f"The list of Numerical columns are {l2}")
# Out:
# The list of categorical columns are ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome', 'y']
# The list of Numerical columns are ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %% [markdown]
# **7)select_dtypes**

# %%
#It gives the data frame
bank_df.select_dtypes(include='object').columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
bank_df.select_dtypes(exclude='object').columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
#categorical columns data
bank_df.select_dtypes(include="object")
# Out:
#                 job  marital  education default housing loan   contact month  \
# 0        unemployed  married    primary      no      no   no  cellular   oct
# 1          services  married  secondary      no     yes  yes  cellular   may
# 2        management   single   tertiary      no     yes   no  cellular   apr
# 3        management  married   tertiary      no     yes  yes   unknown   jun
# 4       blue-collar  married  secondary      no     yes   no   unknown   may
# ...             ...      ...        ...     ...     ...  ...       ...   ...
# 4516       services  married  secondary      no     yes   no  cellular   jul
# 4517  self-employed  married   tertiary     yes     yes  yes   unknown   may
# 4518     technician  married  secondary      no      no   no  cellular   aug
# 4519    blue-collar  married  secondary      no      no   no  cellular   feb
# 4520   entrepreneur   single   tertiary      no     yes  yes  cellular   apr
#
#      poutcome   y
# 0     unknown  no
# ...

# %%
#numerical columns data
bank_df.select_dtypes(exclude='object')
# Out:
#       age  balance  day  duration  campaign  pdays  previous
# 0      30     1787   19        79         1     -1         0
# 1      33     4789   11       220         1    339         4
# 2      35     1350   16       185         1    330         1
# 3      30     1476    3       199         4     -1         0
# 4      59        0    5       226         1     -1         0
# ...   ...      ...  ...       ...       ...    ...       ...
# 4516   33     -333   30       329         5     -1         0
# 4517   57    -3313    9       153         1     -1         0
# 4518   57      295   19       151        11     -1         0
# 4519   28     1137    6       129         4    211         3
# 4520   44     1136    3       345         2    249         7
#
# [4521 rows x 7 columns]

# %% [markdown]
# **8)is_null**

# %%
# is-null is used to check the value is null are missing the values
# It gives out-put in True/False
bank_df.isnull()
# Out:
#         age    job  marital  education  default  balance  housing   loan  \
# 0     False  False    False      False    False    False    False  False
# 1     False  False    False      False    False    False    False  False
# 2     False  False    False      False    False    False    False  False
# 3     False  False    False      False    False    False    False  False
# 4     False  False    False      False    False    False    False  False
# ...     ...    ...      ...        ...      ...      ...      ...    ...
# 4516  False  False    False      False    False    False    False  False
# 4517  False  False    False      False    False    False    False  False
# 4518  False  False    False      False    False    False    False  False
# 4519  False  False    False      False    False    False    False  False
# 4520  False  False    False      False    False    False    False  False
#
#       contact    day  month  duration  campaign  pdays  previous  poutcome  \
# ...

# %%
bank_df.isna()
# Out:
#         age    job  marital  education  default  balance  housing   loan  \
# 0     False  False    False      False    False    False    False  False
# 1     False  False    False      False    False    False    False  False
# 2     False  False    False      False    False    False    False  False
# 3     False  False    False      False    False    False    False  False
# 4     False  False    False      False    False    False    False  False
# ...     ...    ...      ...        ...      ...      ...      ...    ...
# 4516  False  False    False      False    False    False    False  False
# 4517  False  False    False      False    False    False    False  False
# 4518  False  False    False      False    False    False    False  False
# 4519  False  False    False      False    False    False    False  False
# 4520  False  False    False      False    False    False    False  False
#
#       contact    day  month  duration  campaign  pdays  previous  poutcome  \
# ...

# %%
# sum of the Null values
bank_df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# **9)Drop-Duplicate**

# %%
# if any duplicate rows are then drop the row with drop_duplicate
bank_df.drop_duplicates()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bank_df.drop_duplicates().all()
# Out:
# age           True
# job           True
# marital       True
# education     True
# default       True
# balance      False
# housing       True
# loan          True
# contact       True
# day           True
# month         True
# duration      True
# campaign      True
# pdays         True
# previous     False
# poutcome      True
# y             True
# dtype: bool

# %% [markdown]
# **10)INFO**

# %%
# Information of data frame and columns
bank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %% [markdown]
# **11)Take**

# %%
#rows
bank_df.take([100,400,600])
# Out:
#      age          job   marital  education default  balance housing loan  \
# 100   36  blue-collar   married  secondary      no        0     yes   no
# 400   35   technician  divorced   tertiary      no     4515     yes   no
# 600   58      retired  divorced   tertiary      no      264     yes  yes
#
#       contact  day month  duration  campaign  pdays  previous poutcome   y
# 100   unknown    6   may       337         1     -1         0  unknown  no
# 400  cellular   19   nov        98         2     -1         0  unknown  no
# 600  cellular    8   jul       523         3     -1         0  unknown  no

# %%
# axis=1 for columns
bank_df.take([2,8,9],axis=1)
# Out:
#       marital   contact  day
# 0     married  cellular   19
# 1     married  cellular   11
# 2      single  cellular   16
# 3     married   unknown    3
# 4     married   unknown    5
# ...       ...       ...  ...
# 4516  married  cellular   30
# 4517  married   unknown    9
# 4518  married  cellular   19
# 4519  married  cellular    6
# 4520   single  cellular    3
#
# [4521 rows x 3 columns]

# %% [markdown]
# **12)loc**

# %%
#loc will take directly column names
bank_df.loc[100:500,['contact']]
# Out:
#        contact
# 100    unknown
# 101   cellular
# 102  telephone
# 103  telephone
# 104    unknown
# ..         ...
# 496   cellular
# 497   cellular
# 498    unknown
# 499   cellular
# 500   cellular
#
# [401 rows x 1 columns]

# %%
# iloc will give the data for particular row
bank_df.iloc[[300]]
# Out:
#      age      job   marital education default  balance housing loan   contact  \
# 300   70  retired  divorced   primary      no     4531      no   no  cellular
#
#      day month  duration  campaign  pdays  previous poutcome   y
# 300   18   may       445         1     -1         0  unknown  no

# %%
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
# Acess the categrical column in series
bank_df['month']
# Out:
# 0       oct
# 1       may
# 2       apr
# 3       jun
# 4       may
#        ...
# 4516    jul
# 4517    may
# 4518    aug
# 4519    feb
# 4520    apr
# Name: month, Length: 4521, dtype: object

# %%
#Acess the categorical column in dataframe
bank_df[['month']]
# Out:
#      month
# 0      oct
# 1      may
# 2      apr
# 3      jun
# 4      may
# ...    ...
# 4516   jul
# 4517   may
# 4518   aug
# 4519   feb
# 4520   apr
#
# [4521 rows x 1 columns]

# %%
#1) unique () method is only apply on series
bank_df['month'].unique()
# Out:
# array(['oct', 'may', 'apr', 'jun', 'feb', 'aug', 'jan', 'jul', 'nov',
#        'sep', 'mar', 'dec'], dtype=object)

# %%
bank_df[['month']].unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25016\1662604358.py in ?()
# ----> 1 bank_df[['month']].unique()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
len(bank_df['month'].unique())
# Out:
# 12

# %%
#find the length of unique values 2):nunique()
bank_df['month'].nunique()
# Out:
# 12

# %%
bank_df['month']=='oct'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4516    False
# 4517    False
# 4518    False
# 4519    False
# 4520    False
# Name: month, Length: 4521, dtype: bool

# %%
con=bank_df['month']=='oct'
bank_df[con]
# Out:
#       age            job   marital  education default  balance housing loan  \
# 0      30     unemployed   married    primary      no     1787      no   no
# 36     78        retired  divorced    primary      no      229      no   no
# 61     63        retired   married  secondary      no      415     yes   no
# 64     56         admin.   married  secondary      no    16873      no   no
# 97     30         admin.    single   tertiary      no      261      no   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4229   62  self-employed  divorced   tertiary      no        6     yes   no
# 4281   52     management   married  secondary      no      335      no   no
# 4337   73        retired   married    unknown      no      519      no   no
# 4413   65        retired   married    primary      no      493      no   no
# 4423   45     management    single   tertiary      no     2048     yes   no
#
# ...

# %%
unique_count=bank_df['month'].unique()
for i in unique_count:
    con=bank_df['month']==i
    values=len(bank_df[con])
    print(f"{i} : {values}")
# Out:
# oct : 80
# may : 1398
# apr : 293
# jun : 531
# feb : 222
# aug : 633
# jan : 148
# jul : 706
# nov : 389
# sep : 52
# mar : 49
# dec : 20

# %%
# use python to count the number of people in per month
mnt_count=bank_df['month'].unique()
count_list=[]
for i in mnt_count:
    con=bank_df['month']==i
    values=len(bank_df[con])
    count_list.append(values)
month_df=pd.DataFrame(zip(mnt_count,count_list),
                     columns=['Month','Count'])
month_df
# Out:
#    Month  Count
# 0    oct     80
# 1    may   1398
# 2    apr    293
# 3    jun    531
# 4    feb    222
# 5    aug    633
# 6    jan    148
# 7    jul    706
# 8    nov    389
# 9    sep     52
# 10   mar     49
# 11   dec     20

# %% [markdown]
# **value count**

# %%
#value count is used to count the number of peoples in month columns
mnc=bank_df['month'].value_counts()
mnc
# Out:
# month
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# Name: count, dtype: int64

# %%
mnc.keys()
# Out:
# Index(['may', 'jul', 'aug', 'jun', 'nov', 'apr', 'feb', 'jan', 'oct', 'sep',
#        'mar', 'dec'],
#       dtype='object', name='month')

# %%
mnc.values
# Out:
# array([1398,  706,  633,  531,  389,  293,  222,  148,   80,   52,   49,
#          20], dtype=int64)

# %%
mnc.index
# Out:
# Index(['may', 'jul', 'aug', 'jun', 'nov', 'apr', 'feb', 'jan', 'oct', 'sep',
#        'mar', 'dec'],
#       dtype='object', name='month')

# %% [markdown]
# **Bar chart**

# %%
plt.figure(figsize=(10,5)) #change the size of the figure
plt.bar('Month','Count',data=Month_df) #plot
plt.title('Bar Chart') #Title of the plot
plt.xlabel('Month') # x-axis name
plt.ylabel('Count') # y-axis name
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 plt.figure(figsize=(10,5)) #change the size of the figure
# ----> 2 plt.bar('Month','Count',data=Month_df) #plot
#       3 plt.title('Bar Chart') #Title of the plot
#       4 plt.xlabel('Month') # x-axis name
#
# NameError: name 'Month_df' is not defined

# %%
plt.figure(figsize=(10,5))
mnc=bank_df['month'].value_counts()
keys=mnc.keys()
sns.countplot(data=bank_df,x='month',order=keys)
plt.title('Bar chart')
plt.show()

# %%
mnc=bank_df['month'].value_counts()
ax=mnc.plot(kind='bar')
ax.bar_label(ax.containers[0])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#matplotlib
plt.figure(figsize=(8,5))
plt.bar('Month',
       'Count',
       data=month_df)
plt.show()

# %%
#seaborn
cdf=bank_df['month'].value_counts()
keys=cdf.keys()
plt.figure(figsize=(8,5))
sns.countplot(data=bank_df,
             x='month',
             order=keys)
plt.show()

# %%
plt.subplot(1,2,1)
plt.subplot(1,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >
