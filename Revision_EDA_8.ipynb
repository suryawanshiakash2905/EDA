# %%
#importing the packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the data
visa_df=pd.read_csv(r"C:\Users\surya\NareshIT\ EDA_python\Visadataset - Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
#get column name which data type is object
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
#get the columns name which data types is not object
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
#get the column
visa_df[['case_status']]
# Out:
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 1 columns]

# %%
#get the unique value in the column
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
#creating the dictionary
d={'Denied':0,
  'Certified':1}
d
# Out:
# {'Denied': 0, 'Certified': 1}

# %%
#Add the new numerical column from thr categorical
visa_df['case_status_new']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\surya\NareshIT\ EDA_python\Visadataset - Visadataset.csv")
visa_df
d={'Certified':1,
  'Denied':0}
visa_df['case_status_number']=visa_df['case_status'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
d={'N':0,'Y':1}
visa_df['has_job_experience']=visa_df['has_job_experience'].map(d)
visa_df
# Out:
#          case_id continent education_of_employee  has_job_experience  \
# 0         EZYV01      Asia           High School                   0
# 1         EZYV02      Asia              Master's                   1
# 2         EZYV03      Asia            Bachelor's                   0
# 3         EZYV04      Asia            Bachelor's                   0
# 4         EZYV05    Africa              Master's                   1
# ...          ...       ...                   ...                 ...
# 25475  EZYV25476      Asia            Bachelor's                   1
# 25476  EZYV25477      Asia           High School                   1
# 25477  EZYV25478      Asia              Master's                   1
# 25478  EZYV25479      Asia              Master's                   1
# 25479  EZYV25480      Asia            Bachelor's                   1
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
len(visa_df['yr_of_estab'].unique())
# Out:
# 199

# %%
cols=visa_df.select_dtypes(include='object').columns
for i in cols:
    labels=list(visa_df[i].unique())
    values=[i for i in range(len(labels))]
    d=dict(zip(labels,values))
    visa_df[i]=visa_df[i].map(d)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %%
cols=visa_df.select_dtypes(include='object').columns
for i in cols:
    labels=list(visa_df[i].unique())
    values=[i for i in range(len(labels))]
    d=dict(zip(labels,values))
    visa_df[i]=visa_df[i].map(d)
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          0                      0                   0
# 1            1          0                      1                   1
# 2            2          0                      2                   0
# 3            3          0                      2                   0
# 4            4          1                      1                   1
# ...        ...        ...                    ...                 ...
# 25475    25475          0                      2                   1
# 25476    25476          0                      0                   1
# 25477    25477          0                      1                   1
# 25478    25478          0                      1                   1
# 25479    25479          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...
